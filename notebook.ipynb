# %%
import sys
import json
import csv
from pathlib import Path
from dotenv import load_dotenv
# Load environment
load_dotenv()

# Add backend to path
sys.path.insert(0, 'backend')

from app.db.database import get_db

# %%
with get_db() as conn:
    query = "SELECT * FROM article_analysis"
    params = []
    source=None
    # conn = get_db()
    cursor = conn.cursor()
    cursor.execute(query, params)
    rows = cursor.fetchall()
    articles = [dict(row) for row in rows]
    print("articles len: ", len(articles))
    # for article in articles:
    #     print(article)
# Out:
# articles len:  20

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Database path
DB_PATH = Path("data/articles.db")


def get_connection():
    """Get database connection."""
    if not DB_PATH.exists():
        print(f"❌ Database not found at: {DB_PATH}")
        return None
    return sqlite3.connect(DB_PATH)

# %%
conn = get_connection()
if not conn:
    print("None")

query = f"""
SELECT *
FROM article_analysis
"""

df = pd.read_sql_query(query, conn)
conn.close()

print(f"📊 Showing {len(df)} of total articles\n")
df
# Out:
# 📊 Showing 4 of total articles
#                                      id                            article_id  \
# 0  3abed2f2-9186-41ae-8634-ce3e6c3f63b4  0de854af-25e0-4a94-a82e-6e6b70db731b
# 1  4d3df340-e223-4a2d-b9f7-ac86dbc82e01  bfc5a274-786c-47c8-9543-89b03ba02c6d
# 2  13b3eee0-26ab-4cf8-b2f2-b5d8c00b75f5  63c4dd9e-afc3-42eb-8e27-38a6d7f6a151
# 3  b6b5e234-58f8-4003-942d-118b8b5f8914  5ef8d43f-7d59-499a-8624-195b4b0f3032
#
#           subject               category  \
# 0          Vaping  Public Health Studies
# 1           Other  Public Health Studies
# 2           Other  Public Health Studies
# 3  Oral Smokeless  Public Health Studies
#
#                                              summary  \
# 0  This study examined the availability of therap...
# 1  This study examines the intersection of substa...
# 2  This article discusses how influencer-driven p...
# 3  This study examined the use of oral nicotine p...
#
#                                             entities  sentiment  \
# 0  ["nicotine", "vaping", "smoking cessation", "t...    Neutral
# 1      ["alcohol", "tobacco", "addiction", "others"]  Undefined
# 2  ["marijuana", "youth", "social media", "harm r...    Neutral
# 3  ["nicotine", "cigarettes", "electronic cigaret...    Neutral
#
#   industry_affiliation coi_details author_affiliations  ... prompt_used  \
# 0                  n/a        None                None  ...        None
# 1                  n/a        None                None  ...        None
# 2                  n/a        None                None  ...        None
# 3                  n/a        None                None  ...        None
#
#   prompt_version                 analyzed_at analysis_status  \
# 0             v1  2026-08-05T10:58:28.185751       completed
# 1             v1  2026-08-05T11:34:49.143661       completed
# 2             v1  2026-08-05T11:34:09.545958       completed
# 3             v1  2026-08-05T11:34:50.711595       completed
#
#   fact_check_status evaluation_score  \
# 0              None             90.0
# 1              None             83.0
# 2              None             83.0
# 3              None             86.0
#
#                                  evaluation_metadata     stage attempt  \
# 0  {"quality_score": {"factual_accuracy": 95.0, "...  approved       1
# 1  {"quality_score": {"factual_accuracy": 90.0, "...  approved       1
# 2  {"quality_score": {"factual_accuracy": 90.0, "...  approved       1
# 3  {"quality_score": {"factual_accuracy": 90.0, "...  approved       1
#
#                     loaded_at
# 0  2026-08-05T14:46:44.717316
# 1  2026-08-05T14:46:44.724171
# 2  2026-08-05T14:46:44.730032
# 3  2026-08-05T14:46:44.734744
#
# [4 rows x 24 columns]

# %%
# Delete records
# conn = get_connection()
# cursor = conn.cursor()
# cursor.execute("DELETE FROM article_analysis")
# conn.commit()
# conn.close()

# %% [markdown]
# # Database Helper Functions
#
# This notebook uses `db_helper.py` for easy database operations.

# %%
# Import the database helper
from db_helper import *

# Show help
# help()

# %%
# Get database statistics
# get_stats()

# %%
# View all articles (shows last 10 by default)
# df = view_all_articles(limit=50)
# df

# %%
# View CrossRef articles only
# df_crossref = view_by_source('crossref', limit=30)
# df_crossref

# %%
# View PubMed articles only
# df_pubmed = view_by_source('pubmed', limit=30)
# df_pubmed

# %%
# Search for articles with keyword
# df_search = search_articles('reduction', in_field='title', limit=20)
# df_search

# %% [markdown]
# ## Delete Operations
#
# **Warning**: These operations are permanent! Always check the data first.

# %%
# Delete all CrossRef articles (since they have no abstracts)
# First run without confirm=True to see what will be deleted
# delete_by_source('crossref')

# Then uncomment below to actually delete:
# delete_by_source('crossref', confirm=True)

# %%
# Delete a specific article by article_id
# delete_by_article_id('10.1234/example.doi', confirm=True)

# %%
# Export data to CSV
export_to_csv('all_articles.csv')  # Export all
# export_to_csv('pubmed_only.csv', source='pubmed')  # Export PubMed only
# Out:
# ✅ Exported 126 articles to all_articles.csv
# 'all_articles.csv'
